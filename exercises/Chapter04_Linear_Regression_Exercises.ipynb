# %% [markdown]
# # Chapter 04: Bayesian Linear Regression - Bài Tập**Mục tiêu**: Thành thạo Bayesian linear regression**Thời gian**: 4-5 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsimport pymc as pmimport arviz as azimport pandas as pdplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: Simple Linear Regression### 1.1. Generate Data**Câu hỏi**:1. Generate data: y = 2 + 3x + ε, ε ~ N(0, 1²)2. x từ 0 đến 10, 50 points3. Plot data4. Fit OLS regression (sklearn) để compare

# %%
# TODO: Giải bài 1.1# YOUR CODE HERE

# %% [markdown]
# ### 1.2. Bayesian Regression với PyMC**Câu hỏi**:1. Define model:   - Prior cho intercept: N(0, 10²)   - Prior cho slope: N(0, 10²)   - Prior cho σ: HalfNormal(5)2. Sample3. Diagnostics4. Compare với OLS

# %%
# TODO: Giải bài 1.2with pm.Model() as model:    # YOUR CODE HERE    pass# YOUR CODE HERE

# %% [markdown]
# ### 1.3. Prior Predictive Check**Câu hỏi**:1. Sample từ prior predictive2. Plot 100 lines từ prior3. Có reasonable không?4. Thử prior khác nếu cần

# %%
# TODO: Giải bài 1.3# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Posterior Inference### 2.1. Posterior Analysis**Câu hỏi**:1. Plot posterior distributions cho α, β, σ2. Tính posterior means và 95% CI3. Plot posterior regression lines (uncertainty)4. Interpret coefficients

# %%
# TODO: Giải bài 2.1# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Predictions**Câu hỏi**:1. Predict y tại x = 5.52. Plot prediction với uncertainty3. Credible interval vs prediction interval4. Compare với OLS prediction

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: Model Checking### 3.1. Posterior Predictive Checks**Câu hỏi**:1. Generate posterior predictive samples2. Plot data vs predictions3. Check residuals4. Any patterns?

# %%
# TODO: Giải bài 3.1# YOUR CODE HERE

# %% [markdown]
# ### 3.2. Residual Analysis**Câu hỏi**:1. Tính residuals2. Plot residuals vs fitted3. QQ-plot của residuals4. Check assumptions

# %%
# TODO: Giải bài 3.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: Real Data### 4.1. Height-Weight RelationshipData: heights và weights của 100 người**Câu hỏi**:1. Load/generate data2. EDA (scatter plot, correlation)3. Fit Bayesian regression4. Interpret: 1 cm tăng → bao nhiêu kg?5. Predict weight cho height = 170 cm

# %%
# TODO: Giải bài 4.1# Generate synthetic datanp.random.seed(42)heights = np.random.normal(170, 10, 100)  # cmweights = 0.5 * heights - 30 + np.random.normal(0, 5, 100)  # kg# YOUR CODE HERE

# %% [markdown]
# ### 4.2. Model ComparisonSo sánh 3 models:1. Linear: y = α + βx2. Quadratic: y = α + β₁x + β₂x²3. Robust (Student-t errors)**Câu hỏi**:1. Fit cả 3 models2. Compare predictions3. Which one best?4. Use LOO or WAIC (preview)

# %%
# TODO: Giải bài 4.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Informative Priors### 5.1. Prior từ Domain KnowledgeBạn biết từ research trước: slope nên gần 3, không thể âm**Câu hỏi**:1. Design informative prior cho slope2. Fit model3. Compare với uninformative prior4. Prior có ảnh hưởng nhiều không?

# %%
# TODO: Giải bài 5.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Fit Bayesian linear regression với PyMC- [ ] Prior và posterior predictive checks- [ ] Interpret coefficients với uncertainty- [ ] Make predictions với credible intervals- [ ] Residual analysis- [ ] Compare models**Nếu chưa tự tin → Review Chapter 04!**

# %% [markdown]
# # Chapter 02: Probability & Updating - Bài Tập**Mục tiêu**: Thành thạo likelihood, prior, posterior, và conjugate priors**Thời gian**: 4-5 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: Likelihood### 1.1. Binomial LikelihoodTung đồng xu 10 lần, được 7 lần ngửa.**Câu hỏi**:1. Vẽ likelihood function L(θ | data) với θ từ 0 đến 12. Tìm MLE (Maximum Likelihood Estimate)3. Tính likelihood tại θ = 0.5, 0.6, 0.7, 0.8

# %%
# TODO: Giải bài 1.1# YOUR CODE HERE

# %% [markdown]
# ### 1.2. Normal LikelihoodDữ liệu: [1.2, 1.5, 1.8, 1.3, 1.6] ~ N(μ, σ²=0.1²)**Câu hỏi**:1. Vẽ likelihood L(μ | data)2. Tìm MLE cho μ3. So sánh với sample mean

# %%
# TODO: Giải bài 1.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Prior Distributions### 2.1. Prior ChoiceBạn đang ước lượng tỷ lệ chuyển đổi của website (conversion rate).**Câu hỏi**:1. Vẽ 3 priors khác nhau: uninformative, weakly informative, informative2. Giải thích khi nào dùng mỗi loại3. Implement prior predictive check

# %%
# TODO: Giải bài 2.1# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Prior SensitivityDữ liệu: 8 thành công trong 10 thử**Câu hỏi**:1. Thử 3 priors: Beta(1,1), Beta(2,2), Beta(10,10)2. Tính posterior cho mỗi prior3. So sánh và nhận xét về prior sensitivity

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: Posterior Inference### 3.1. Beta-BinomialPrior: Beta(2, 2)Data: 15 thành công trong 20 thử**Câu hỏi**:1. Tính posterior2. Vẽ prior, likelihood, và posterior trên cùng 1 plot3. Tính posterior mean, mode, 95% credible interval4. Tính P(θ > 0.7 | data)

# %%
# TODO: Giải bài 3.1# YOUR CODE HERE

# %% [markdown]
# ### 3.2. Sequential UpdatingPrior: Beta(2, 2)Dữ liệu đến từng đợt:- Batch 1: 5 successes, 2 failures- Batch 2: 8 successes, 3 failures- Batch 3: 3 successes, 4 failures**Câu hỏi**:1. Update posterior sau mỗi batch2. Vẽ evolution3. So sánh với posterior từ tất cả data cùng lúc

# %%
# TODO: Giải bài 3.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: Conjugate Priors### 4.1. Normal-NormalPrior: N(μ₀=10, σ₀²=2²)Data: [12, 11, 13, 10, 14] với σ²=1² (known)**Câu hỏi**:1. Tính posterior analytically2. Verify bằng grid approximation3. Vẽ prior, likelihood, posterior

# %%
# TODO: Giải bài 4.1# YOUR CODE HERE

# %% [markdown]
# ### 4.2. Gamma-PoissonPrior: Gamma(α=2, β=1)Data: [3, 5, 4, 6, 2] (counts)**Câu hỏi**:1. Tính posterior2. Posterior predictive distribution3. Tính P(next observation > 5)

# %%
# TODO: Giải bài 4.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Grid Approximation### 5.1. Non-conjugate CaseLikelihood: BinomialPrior: Triangular (peak tại 0.5)Data: 7 successes trong 10 trials**Câu hỏi**:1. Implement grid approximation với 100 grid points2. Tính posterior3. Tính posterior mean và 95% CI4. So sánh với conjugate prior Beta(1,1)

# %%
# TODO: Giải bài 5.1# YOUR CODE HERE

# %% [markdown]
# ### 5.2. 2D Grid ApproximationEstimate cả μ và σ từ data: [1.2, 1.5, 1.8, 1.3, 1.6]**Câu hỏi**:1. Grid approximation 2D (μ, σ)2. Vẽ contour plot của posterior3. Tìm MAP (Maximum A Posteriori)4. Tính marginal posterior cho μ

# %%
# TODO: Giải bài 5.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 6: Real Application### 6.1. Clinical TrialDrug trial: 45 patients recovered trong 60 patientsPrior belief: Beta(10, 10) (skeptical)**Câu hỏi**:1. Tính posterior2. P(recovery rate > 0.7)?3. P(recovery rate > 0.5)? (better than placebo)4. 95% credible interval5. Posterior predictive: P(next 10 patients, at least 7 recover)?

# %%
# TODO: Giải bài 6.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Hiểu và tính likelihood- [ ] Chọn prior phù hợp- [ ] Tính posterior (conjugate và grid)- [ ] Sequential updating- [ ] Posterior inference (mean, CI, probabilities)- [ ] Posterior predictive checks**Nếu chưa tự tin → Review Chapter 02!**

# %% [markdown]
# # Chapter 07: Priors & Regularization - Bài Tập**Mục tiêu**: Hiểu regularization thông qua priors**Thời gian**: 3-4 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsimport pymc as pmimport arviz as azimport pandas as pdfrom sklearn.model_selection import train_test_splitplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: Overfitting### 1.1. Polynomial OverfittingData: y = x + x² + noise, n = 20**Câu hỏi**:1. Fit polynomials degree 1, 3, 5, 10, 152. Plot fits3. Which one overfits?4. Train/test split và compare errors

# %%
# TODO: Giải bài 1.1# YOUR CODE HERE

# %% [markdown]
# ### 1.2. Bias-Variance Tradeoff**Câu hỏi**:1. Repeat experiment 100 times2. Tính bias và variance cho mỗi degree3. Plot bias-variance tradeoff4. Optimal degree?

# %%
# TODO: Giải bài 1.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Regularization với Priors### 2.1. Ridge Regression (L2)**Câu hỏi**:1. Fit polynomial degree 10 với different priors:   - Flat: N(0, 100²)   - Weak: N(0, 10²)   - Strong: N(0, 1²)2. Compare coefficients3. Compare predictions4. Which prior best?

# %%
# TODO: Giải bài 2.1# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Lasso Regression (L1)**Câu hỏi**:1. Use Laplace prior (L1 regularization)2. Fit model3. Check coefficient shrinkage4. Compare với Ridge

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: Prior Choice### 3.1. Prior SensitivityData: Simple regression với n = 10**Câu hỏi**:1. Thử 5 different priors cho slope2. Compare posteriors3. Prior có ảnh hưởng nhiều không?4. Thử lại với n = 100

# %%
# TODO: Giải bài 3.1# YOUR CODE HERE

# %% [markdown]
# ### 3.2. Informative vs Uninformative**Câu hỏi**:1. Scenario: Bạn biết slope nên gần 22. Design informative prior3. Compare với flat prior4. Khi nào nên dùng informative prior?

# %%
# TODO: Giải bài 3.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: Regularization Strength### 4.1. Cross-validation**Câu hỏi**:1. Thử different prior standard deviations: 0.1, 1, 10, 1002. 5-fold CV để chọn best3. Plot CV error vs prior strength4. Optimal regularization?

# %%
# TODO: Giải bài 4.1# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Real Application - Feature SelectionData: y ~ 20 predictors, nhưng chỉ 5 thực sự relevant**Câu hỏi**:1. Generate data2. Fit với flat priors (overfitting?)3. Fit với regularization priors4. Compare coefficients5. Which features selected?6. Test set performance

# %%
# TODO: Giải bài 5# Generate datanp.random.seed(42)n = 100p = 20X = np.random.randn(n, p)# Only first 5 features mattertrue_coef = np.zeros(p)true_coef[:5] = [2, -1.5, 3, -2, 1]y = X @ true_coef + np.random.randn(n)# YOUR CODE HERE

# %% [markdown]
# ## Bài 6: Hierarchical Priors### 6.1. Automatic Regularization**Câu hỏi**:1. Implement hierarchical prior:   - β ~ N(0, τ²)   - τ ~ HalfCauchy(1)2. Fit model3. Posterior của τ?4. Compare với fixed regularization

# %%
# TODO: Giải bài 6.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Hiểu overfitting- [ ] Bias-variance tradeoff- [ ] Regularization với priors (Ridge, Lasso)- [ ] Prior sensitivity analysis- [ ] Cross-validation- [ ] Feature selection- [ ] Hierarchical priors**Nếu chưa tự tin → Review Chapter 07!**

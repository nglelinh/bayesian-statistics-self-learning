# %% [markdown]
# # Chapter 06: Bayesian GLM - Bài Tập**Mục tiêu**: Thành thạo logistic và Poisson regression**Thời gian**: 4-5 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsimport pymc as pmimport arviz as azimport pandas as pdplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: Logistic Regression Basics### 1.1. Generate Binary Data**Câu hỏi**:1. Generate: logit(p) = -1 + 2x2. x ~ N(0, 1), n = 2003. Plot p(x) và data4. Visualize decision boundary

# %%
# TODO: Giải bài 1.1# YOUR CODE HERE

# %% [markdown]
# ### 1.2. Fit Logistic Regression**Câu hỏi**:1. Fit với PyMC2. Priors: N(0, 5²) cho coefficients3. Check diagnostics4. Plot posterior predictive5. Compare với sklearn LogisticRegression

# %%
# TODO: Giải bài 1.2# YOUR CODE HERE

# %% [markdown]
# ### 1.3. Interpret Coefficients**Câu hỏi**:1. Posterior mean của β2. Tính odds ratio: exp(β)3. Interpret: 1 unit tăng x → odds tăng bao nhiêu?4. Tính P(y=1 | x=0) và P(y=1 | x=1)

# %%
# TODO: Giải bài 1.3# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Multivariate Logistic Regression### 2.1. Multiple Predictorsy ~ logit⁻¹(α + β₁x₁ + β₂x₂)**Câu hỏi**:1. Generate data2. Fit model3. Interpret coefficients4. Partial dependence plots

# %%
# TODO: Giải bài 2.1# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Model Evaluation**Câu hỏi**:1. Confusion matrix2. ROC curve và AUC3. Calibration plot4. Posterior predictive checks

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: Real Application - Churn PredictionData: Customer churn ~ Age + Tenure + MonthlyCharges**Câu hỏi**:1. Generate/load data2. EDA3. Fit logistic regression4. Interpret: Factors ảnh hưởng churn?5. Predict churn probability cho new customer6. Decision: Threshold nào để retain?

# %%
# TODO: Giải bài 3# Generate datanp.random.seed(42)n = 500age = np.random.uniform(20, 70, n)tenure = np.random.uniform(0, 10, n)  # yearsmonthly_charges = np.random.uniform(20, 150, n)logit_p = -2 + 0.02*age - 0.5*tenure + 0.02*monthly_chargesp = 1 / (1 + np.exp(-logit_p))churn = np.random.binomial(1, p, n)# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: Poisson Regression### 4.1. Count DataGenerate: log(λ) = 1 + 0.5x**Câu hỏi**:1. Generate count data2. Plot histogram3. Fit Poisson regression4. Check overdispersion

# %%
# TODO: Giải bài 4.1# YOUR CODE HERE

# %% [markdown]
# ### 4.2. Interpret Coefficients**Câu hỏi**:1. Posterior của β2. Tính rate ratio: exp(β)3. Interpret: 1 unit tăng x → rate tăng bao nhiêu?4. Predict counts tại x = 0, 1, 2

# %%
# TODO: Giải bài 4.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Real Application - Website VisitsData: Daily visits ~ DayOfWeek + IsHoliday + Temperature**Câu hỏi**:1. Generate data2. Fit Poisson regression3. Interpret effects4. Predict visits cho specific day5. Posterior predictive checks

# %%
# TODO: Giải bài 5# YOUR CODE HERE

# %% [markdown]
# ## Bài 6: Overdispersion### 6.1. Negative BinomialData có overdispersion (variance > mean)**Câu hỏi**:1. Generate overdispersed count data2. Fit Poisson (wrong)3. Fit Negative Binomial (correct)4. Compare models5. Check posterior predictive

# %%
# TODO: Giải bài 6.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Fit logistic regression- [ ] Interpret odds ratios- [ ] Model evaluation (ROC, calibration)- [ ] Fit Poisson regression- [ ] Interpret rate ratios- [ ] Handle overdispersion**Nếu chưa tự tin → Review Chapter 06!**

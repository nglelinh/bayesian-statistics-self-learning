# %% [markdown]
# # Chapter 03: MCMC - Bài Tập**Mục tiêu**: Thành thạo MCMC sampling và diagnostics**Thời gian**: 5-6 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsimport pymc as pmimport arviz as azplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: Monte Carlo Basics### 1.1. Estimating Pi**Câu hỏi**:1. Estimate π bằng Monte Carlo (throw darts)2. Thử với 100, 1000, 10000, 100000 samples3. Vẽ convergence plot4. Tính standard error

# %%
# TODO: Giải bài 1.1# YOUR CODE HERE

# %% [markdown]
# ### 1.2. IntegrationTính integral: ∫₀¹ x² dx bằng Monte Carlo**Câu hỏi**:1. Estimate bằng MC2. So sánh với analytical result (1/3)3. Tính error với different sample sizes

# %%
# TODO: Giải bài 1.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Metropolis-Hastings### 2.1. Implement MH từ đầuTarget: Beta(5, 2)Proposal: Normal random walk**Câu hỏi**:1. Implement MH algorithm2. Run 10000 iterations3. Vẽ trace plot4. Tính acceptance rate5. Compare với true Beta(5,2)

# %%
# TODO: Giải bài 2.1def metropolis_hastings(target_pdf, proposal_std, n_iterations, initial_value):    """    Metropolis-Hastings algorithm    """    # YOUR CODE HERE    pass# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Tuning ProposalThử different proposal standard deviations: 0.01, 0.1, 1.0, 10.0**Câu hỏi**:1. Run MH với mỗi proposal std2. Tính acceptance rate3. Vẽ trace plots4. Tính effective sample size5. Proposal nào tốt nhất?

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: MCMC Diagnostics### 3.1. Trace Plots và ConvergenceRun 4 chains với different initial values cho Beta(5, 2)**Câu hỏi**:1. Vẽ trace plots cho 4 chains2. Visual inspection: converged?3. Tính R-hat4. Tính ESS (Effective Sample Size)5. Cần bao nhiêu samples?

# %%
# TODO: Giải bài 3.1# YOUR CODE HERE

# %% [markdown]
# ### 3.2. Autocorrelation**Câu hỏi**:1. Vẽ autocorrelation plot2. Tính autocorrelation lag3. Thin samples để reduce autocorrelation4. So sánh ESS trước và sau thinning

# %%
# TODO: Giải bài 3.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: PyMC Implementation### 4.1. Beta-Binomial với PyMCData: 15 successes trong 20 trials**Câu hỏi**:1. Define model trong PyMC2. Sample với NUTS3. Check diagnostics (R-hat, ESS, divergences)4. Plot posterior5. Posterior summary

# %%
# TODO: Giải bài 4.1with pm.Model() as model:    # YOUR CODE HERE    pass# YOUR CODE HERE

# %% [markdown]
# ### 4.2. Normal ModelData: [1.2, 1.5, 1.8, 1.3, 1.6, 1.4, 1.7]Estimate μ và σ**Câu hỏi**:1. Define model (priors cho μ và σ)2. Sample3. Diagnostics4. Joint posterior plot5. Marginal posteriors

# %%
# TODO: Giải bài 4.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Posterior Predictive Checks### 5.1. Binomial ModelData: 7 successes trong 10 trials**Câu hỏi**:1. Fit model với PyMC2. Generate posterior predictive samples3. Plot posterior predictive distribution4. Check: Data consistent với model?

# %%
# TODO: Giải bài 5.1# YOUR CODE HERE

# %% [markdown]
# ### 5.2. Normal ModelData: [1.2, 1.5, 1.8, 1.3, 1.6]**Câu hỏi**:1. Posterior predictive checks2. Plot data vs predictions3. Check residuals4. Any model misspecification?

# %%
# TODO: Giải bài 5.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 6: Challenging Problems### 6.1. Mixture ModelData có 2 modes: [1.0, 1.2, 1.1, 4.8, 5.0, 5.2, 4.9]**Câu hỏi**:1. Fit mixture of 2 Normals2. Check convergence (might be hard!)3. Interpret results4. Posterior predictive check

# %%
# TODO: Giải bài 6.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Hiểu Monte Carlo methods- [ ] Implement Metropolis-Hastings- [ ] Tune proposal distributions- [ ] Check MCMC diagnostics (R-hat, ESS, trace plots)- [ ] Sử dụng PyMC thành thạo- [ ] Posterior predictive checks**Nếu chưa tự tin → Review Chapter 03!**

# %% [markdown]
# # Chapter 01: Bayesian Inference - Bài Tập**Mục tiêu**: Hiểu triết lý Bayesian và critique của p-values**Thời gian**: 3-4 giờ---

# %%
import numpy as npimport matplotlib.pyplot as pltfrom scipy import statsimport seaborn as snsplt.style.use('seaborn-v0_8-darkgrid')np.random.seed(42)

# %% [markdown]
# ## Bài 1: P-values và Vấn đề### 1.1. Diễn giải P-valueMột nghiên cứu báo cáo: "p = 0.03 cho test so sánh hai nhóm"**Câu hỏi**: Đánh dấu câu nào ĐÚNG:1. [ ] Xác suất H₀ đúng là 3%2. [ ] Xác suất kết quả do ngẫu nhiên là 3%3. [ ] Nếu H₀ đúng, xác suất quan sát kết quả cực đoan như vậy là 3%4. [ ] Xác suất H₁ đúng là 97%**Giải thích** câu trả lời của bạn:

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### 1.2. P-hacking SimulationMô phỏng p-hacking: Test 20 biến khác nhau, chỉ báo cáo biến có p < 0.05**Câu hỏi**: 1. Lặp lại 1000 lần, tính tỷ lệ có ít nhất 1 "significant" result2. So sánh với α = 0.05

# %%
# TODO: Mô phỏng p-hackingdef phacking_simulation(n_variables=20, n_samples=100, n_simulations=1000):    """    Mô phỏng p-hacking với nhiều biến    """    # YOUR CODE HERE    pass# Run simulation# YOUR CODE HERE

# %% [markdown]
# ## Bài 2: Bayes' Theorem### 2.1. Medical TestTest ung thư có:- Sensitivity: 90% (P(+ | Cancer))- Specificity: 95% (P(- | No Cancer))- Prevalence: 1%**Câu hỏi**:1. Tính P(Cancer | +)2. Vẽ diagram minh họa3. Nếu test 2 lần đều dương tính, P(Cancer)?

# %%
# TODO: Giải bài 2.1# YOUR CODE HERE

# %% [markdown]
# ### 2.2. Sequential UpdatingBắt đầu với prior: P(θ) = Beta(2, 2)Nhận dữ liệu từng đợt:- Đợt 1: 3 thành công, 2 thất bại- Đợt 2: 5 thành công, 1 thất bại- Đợt 3: 2 thành công, 3 thất bại**Câu hỏi**: 1. Tính posterior sau mỗi đợt2. Vẽ evolution của posterior3. Verify: Thứ tự có quan trọng không?

# %%
# TODO: Giải bài 2.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 3: Bayesian vs Frequentist### 3.1. Confidence Interval vs Credible IntervalDữ liệu: 15 thành công trong 20 thử**Câu hỏi**:1. Tính 95% confidence interval (frequentist)2. Tính 95% credible interval (Bayesian với prior Beta(1,1))3. Viết diễn giải ĐÚNG cho mỗi loại4. Mô phỏng: Lặp lại 1000 lần, tính coverage của CI

# %%
# TODO: Giải bài 3.1# YOUR CODE HERE

# %% [markdown]
# ### 3.2. P-value vs Posterior ProbabilityDữ liệu: 8 thành công trong 10 thửTest H₀: θ = 0.5**Câu hỏi**:1. Tính p-value (frequentist)2. Tính P(θ > 0.5 | data) (Bayesian với prior Beta(2,2))3. So sánh và giải thích sự khác biệt

# %%
# TODO: Giải bài 3.2# YOUR CODE HERE

# %% [markdown]
# ## Bài 4: Probability as Plausibility### 4.1. Monty Hall ProblemBạn chọn cửa 1. Host mở cửa 3 (có dê). Bạn có nên đổi sang cửa 2?**Câu hỏi**:1. Tính P(Car behind door 2 | Host opens door 3)2. Mô phỏng 10000 lần để verify3. Giải thích bằng Bayesian reasoning

# %%
# TODO: Giải bài 4.1def monty_hall_simulation(n_simulations=10000, switch=True):    """    Mô phỏng Monty Hall problem    """    # YOUR CODE HERE    pass# YOUR CODE HERE

# %% [markdown]
# ## Bài 5: Real Data Analysis### 5.1. A/B TestingWebsite A/B test:- Version A: 120 conversions trong 1000 visitors- Version B: 145 conversions trong 1000 visitors**Câu hỏi**:1. **Frequentist**: Tính p-value cho test hai tỷ lệ2. **Bayesian**:    - Prior: Beta(2, 2) cho cả hai   - Tính posterior cho p_A và p_B   - Tính P(p_B > p_A | data)   - Tính expected loss nếu chọn sai3. **Decision**: Bạn chọn version nào? Tại sao?

# %%
# TODO: Giải bài 5.1# YOUR CODE HERE

# %% [markdown]
# ---## 🎯 Tự đánh giáSau khi hoàn thành:- [ ] Hiểu vấn đề của p-values- [ ] Diễn giải ĐÚNG p-values và CI- [ ] Thành thạo Bayes' Theorem- [ ] Hiểu sequential updating- [ ] So sánh Bayesian vs Frequentist- [ ] Áp dụng cho real problems**Nếu chưa tự tin → Review Chapter 01!**

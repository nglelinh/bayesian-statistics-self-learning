# %% [markdown]
# # Phân tích dữ liệu Bayesian - IUH.
#
# ### Lab 4. Ngày 28/02/2024.
#
# > Mục tiêu:
# - Ôn tập về công thức của phân phối chuẩn.
# - Ôn tập về các dạng liên hợp.
# - Ôn tập về việc vẽ đồ thị cho các phân phối liên tục.

# %% [markdown]
# **Bài 1.** Cho biến ngẫu nhiên $X$ có phân phối chuẩn với $\mu = 4, \sigma = -1.$ Tính xác suất có điều kiện $$P(X \le 0 | X > -3).$$

# %%
#CODE HERE

# %% [markdown]
# **Bài 2.** Cho $X$ là biến ngẫu nhiên liên tục có hàm mật độ xác suất $$f_X(x) = 2x \text{ với } 0 \le x \le 1.$$ Tìm hậu nghiệm cho $X$ biết rằng các likelihood cho bởi các hàm sau:
# - a) Giả sử $Y|X = x \sim Geometric(x)$.
# - b) Giả sử $Y|X = x \sim Binomial(4,x).$
# - c) Giả sử $Y|X = x \sim Poisson(x).$

# %%
#CODE HERE

# %% [markdown]
# **Bài 3.** Theo kinh nghiệm giảng dạy vài năm của thầy $S$ thì tỷ lệ qua môn Bayesian là $80\%$ với độ lệch chuẩn $10\%$ theo phân phối Beta. Trong học kỳ vừa rồi, lớp học có $40$ sinh viên thì có $35$ em qua môn.
# - a) Hãy dùng phương pháp Bayesian để tìm phân phối hậu nghiệm.
# - b) Tính rủi ro hậu nghiệm.
# - c) Vẽ đồ thị của phân phối Beta trước và sau quan sát.

# %%
#CODE HERE

# %% [markdown]
# **Bài 4.** Dựa theo đánh giá tình hình học tập các môn khác, thầy $T$ thấy rằng xác suất để em Nam thi đậu TOEIC là $p$ có phân bố đều trên $(0.75;1).$ Em Nam sẽ thi đến khi nào đậu thì thôi. Biết rằng em Nam đã thi tất cả $3$ lần. Tìm hàm mật độ hậu nghiệm của $p$ và tính xác suất để $p < 0.8.$

# %%
#CODE HERE

# %% [markdown]
# **Bài 5.** Quan sát tình hình đi học của lớp, thầy $L$ thấy rằng số sinh viên nghỉ học không phép ở lớp Bayesian có trung bình bằng $3$ với độ lệch chuẩn là $2$ theo phân phối Gamma. Quan sát trong $8$ tuần vừa rồi, thầy thấy số sinh viên nghỉ là dãy $$2,0,2,3,2,0,2,4$$ với phân phối Poisson. Hãy dùng phương pháp Bayesian để tìm phân phối hậu nghiệm và vẽ đồ thị sau từng lần quan sát.

# %%
#CODE HERE
